# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ferran Pedrero**
#
# Sales Analyst

# %% [markdown]
# *I am interested in data science because I feel I can learn about ways of bringin value to business in an unique and insightful ways.*

# %% [markdown]
# # My Next Cell Is Going To Do The Sum Up Of 3 Different Numbers And Print The Result

# %%
sum_up=4+5+6
print(sum_up)
# Out:
# 15

# %% [markdown]
# * Shopping List
#   * Carrots
#   * Cucumber
#   * Potatoes
#
# 1. Get the Cucumber
# 2. Then Buy The Carrots
# 3. Get Potatoes
#
# ![Where?](https://cdn02.visitbarcelona.com/files/5445-10407-Imagen/Barcelona_Shopping_City_c2.jpg)
